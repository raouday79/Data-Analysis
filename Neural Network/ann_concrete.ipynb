# %%
import  pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv("concrete.csv")

# %%
data.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# cement          1030 non-null float64
# slag            1030 non-null float64
# ash             1030 non-null float64
# water           1030 non-null float64
# superplastic    1030 non-null float64
# coarseagg       1030 non-null float64
# fineagg         1030 non-null float64
# age             1030 non-null int64
# strength        1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
x = data.iloc[:,0:8].values
y = data.iloc[:,8:9].values

# %%
data.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# 25%     932.000000   730.950000     7.000000    23.710000
# 50%     968.000000   779.500000    28.000000    34.445000
# 75%    1029.400000   824.000000    56.000000    46.135000
# max    1145.000000   992.600000   365.000000    82.600000

# %%
from sklearn.model_selection  import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
y
# Out:
# array([[29.89],
#        [23.51],
#        [29.22],
#        ...,
#        [44.28],
#        [55.06],
#        [52.61]])

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
model = Sequential()
model.add(Dense(units=256,kernel_initializer="normal",activation="relu"))
model.add(Dense(units=256,kernel_initializer="normal",activation="relu"))
model.add(Dense(units=256,kernel_initializer="normal",activation="relu"))
model.add(Dense(units=1,kernel_initializer="normal",activation="linear"))
model.compile(loss="mean_absolute_error",optimizer="adam",metrics=['mean_absolute_error'])
model.fit(x_train,y_train,batch_size=10,epochs=50)
model.summary()
# Out:
# Train on 824 samples
# Epoch 1/50
# 824/824 [==============================] - 3s 4ms/sample - loss: 18.9373 - mean_absolute_error: 18.9373
# Epoch 2/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 11.0467 - mean_absolute_error: 11.0467
# Epoch 3/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 9.6931 - mean_absolute_error: 9.6931
# Epoch 4/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 9.1925 - mean_absolute_error: 9.1925
# Epoch 5/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 8.0484 - mean_absolute_error: 8.0484
# Epoch 6/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 7.0632 - mean_absolute_error: 7.0632
# Epoch 7/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 6.1784 - mean_absolute_error: 6.1784
# Epoch 8/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 5.6010 - mean_absolute_error: 5.6010
# Epoch 9/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 5.3110 - mean_absolute_error: 5.3110
# Epoch 10/50
# 824/824 [==============================] - 1s 809us/sample - loss: 5.2683 - mean_absolute_error: 5.2683
# Epoch 11/50
# 824/824 [==============================] - 1s 744us/sample - loss: 5.1932 - mean_absolute_error: 5.1932
# Epoch 12/50
# 824/824 [==============================] - 1s 741us/sample - loss: 4.8812 - mean_absolute_error: 4.8812
# Epoch 13/50
# 824/824 [==============================] - 1s 812us/sample - loss: 4.8293 - mean_absolute_error: 4.8293
# Epoch 14/50
# 824/824 [==============================] - 1s 780us/sample - loss: 4.7020 - mean_absolute_error: 4.7020
# Epoch 15/50
# 824/824 [==============================] - 1s 774us/sample - loss: 4.7648 - mean_absolute_error: 4.7648
# Epoch 16/50
# 824/824 [==============================] - 1s 778us/sample - loss: 4.8772 - mean_absolute_error: 4.8772
# Epoch 17/50
# 824/824 [==============================] - 1s 783us/sample - loss: 4.4188 - mean_absolute_error: 4.4188
# Epoch 18/50
# 824/824 [==============================] - 1s 786us/sample - loss: 4.5157 - mean_absolute_error: 4.5157
# Epoch 19/50
# 824/824 [==============================] - 1s 814us/sample - loss: 4.3098 - mean_absolute_error: 4.3098
# Epoch 20/50
# 824/824 [==============================] - 1s 814us/sample - loss: 4.3044 - mean_absolute_error: 4.3044
# Epoch 21/50
# 824/824 [==============================] - 1s 828us/sample - loss: 4.1345 - mean_absolute_error: 4.1345
# Epoch 22/50
# 824/824 [==============================] - 1s 776us/sample - loss: 4.1518 - mean_absolute_error: 4.1518
# Epoch 23/50
# 824/824 [==============================] - 1s 833us/sample - loss: 4.5096 - mean_absolute_error: 4.5096
# Epoch 24/50
# 824/824 [==============================] - 1s 778us/sample - loss: 4.0705 - mean_absolute_error: 4.0705
# Epoch 25/50
# 824/824 [==============================] - 1s 776us/sample - loss: 4.3141 - mean_absolute_error: 4.3141
# Epoch 26/50
# 824/824 [==============================] - 1s 775us/sample - loss: 4.1319 - mean_absolute_error: 4.1319
# Epoch 27/50
# 824/824 [==============================] - 1s 783us/sample - loss: 4.1133 - mean_absolute_error: 4.1133
# Epoch 28/50
# 824/824 [==============================] - 1s 882us/sample - loss: 4.0505 - mean_absolute_error: 4.0505
# Epoch 29/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 4.0400 - mean_absolute_error: 4.0400
# Epoch 30/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.8481 - mean_absolute_error: 3.8481
# Epoch 31/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.9705 - mean_absolute_error: 3.9705
# Epoch 32/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.9158 - mean_absolute_error: 3.9158
# Epoch 33/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.9222 - mean_absolute_error: 3.9222
# Epoch 34/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.9941 - mean_absolute_error: 3.9941
# Epoch 35/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.9048 - mean_absolute_error: 3.9048
# Epoch 36/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.7641 - mean_absolute_error: 3.7641
# Epoch 37/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.7110 - mean_absolute_error: 3.7110
# Epoch 38/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.6168 - mean_absolute_error: 3.6168
# Epoch 39/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.5992 - mean_absolute_error: 3.5992
# Epoch 40/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.6291 - mean_absolute_error: 3.6291
# Epoch 41/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.8515 - mean_absolute_error: 3.8515
# Epoch 42/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.5301 - mean_absolute_error: 3.5301
# Epoch 43/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.5023 - mean_absolute_error: 3.5023
# Epoch 44/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.5637 - mean_absolute_error: 3.5637
# Epoch 45/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.5745 - mean_absolute_error: 3.5745
# Epoch 46/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.5817 - mean_absolute_error: 3.5817
# Epoch 47/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.4174 - mean_absolute_error: 3.4174
# Epoch 48/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.4513 - mean_absolute_error: 3.4513
# Epoch 49/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.4463 - mean_absolute_error: 3.4463
# Epoch 50/50
# 824/824 [==============================] - 1s 1ms/sample - loss: 3.4749 - mean_absolute_error: 3.4749
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  2304
# _________________________________________________________________
# dense_1 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_2 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_3 (Dense)              multiple                  257
# =================================================================
# Total params: 134,145
# Trainable params: 134,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
m

# %%
y_test

# %%
m = model.predict(x_test)

# %%
model.evaluate(x_test,y_test)
# Out:
# 206/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [4.196842901915023, 4.1968427]
